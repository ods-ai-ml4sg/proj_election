# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/'My Drive'/urn.zip
# Out:
# Archive:  /content/drive/My Drive/urn.zip
#    creating: urn/
#    creating: urn/test/
#    creating: urn/test/images/
#   inflating: urn/test/images/DSC05350_jpg.rf.0c5b5e535d5ad1a4535c2568441d3f77.jpg
#   inflating: urn/test/images/b9d6c14a89b78915943f4e1cfbf30654_jpg.rf.219da5a8a3915ce0ae71fa5c404dd123.jpg
#   inflating: urn/test/images/1e55abdfef02ae67d1783d8adf3c5598_jpg.rf.2aa0ade1cfdbc84f0ed202e580a241d7.jpg
#   inflating: urn/test/images/DYjGapNWsAAGpfJ_jpg.rf.6fd8141f1073ce0ee59bf91e452575a9.jpg
#   inflating: urn/test/images/%D0%BF%D0%B0%D1%80%D0%B0%D0%BC%D0%BE%D0%BD%D0%BE%D_jpg.rf.8484d5bcaa09b4f1d967ac22bbf44516.jpg
#   inflating: urn/test/images/ZrJ-XGTzNSA_jpg.rf.9b0c176b0415ad14d8e524b008edb91e.jpg
#   inflating: urn/test/images/1_2-98_jpg.rf.0e5f610ace63d0a9837f9c125bc1f30b.jpg
#   inflating: urn/test/images/468874_jpg.rf.706fe5df5fe34c810d4889387628c31a.jpg
#   inflating: urn/test/images/IMG_5240_jpg.rf.218978a26e35a6ee3203adeac1582db3.jpg
# ...

# %%
# !git clone  'https://github.com/ultralytics/yolov5.git'

# !pip install -qr '/content/yolov5/requirements.txt'
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 84, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 3005 (delta 53), reused 52 (delta 27), pack-reused 2921
# Receiving objects: 100% (3005/3005), 6.37 MiB | 36.06 MiB/s, done.
# Resolving deltas: 100% (1997/1997), done.
#      |████████████████████████████████| 276kB 19.6MB/s
# ...

# %%
# !python /content/yolov5/train.py --img 416 --batch 16 --epochs 100 --data '/content/yolov5/data/urn.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --name urn_detection --cache
# Out:
# Using torch 1.7.0+cu101 CUDA:0 (Tesla T4, 15079MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=True, cfg='/content/yolov5/models/yolov5s.yaml', data='/content/yolov5/data/urn.yaml', device='', epochs=100, evolve=False, exist_ok=False, global_rank=-1, hyp='./yolov5/data/hyp.scratch.yaml', image_weights=False, img_size=[416, 416], local_rank=-1, log_imgs=16, multi_scale=False, name='urn_detection', noautoanchor=False, nosave=False, notest=False, project='runs/train', rect=False, resume=False, save_dir='runs/train/urn_detection', single_cls=False, sync_bn=False, total_batch_size=16, weights='yolov5s.pt', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# 2020-11-18 18:24:17.992092: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !python yolov5/detect.py --source /content/urn/test/images --weights '/content/runs/train/urn_detection/weights/best.pt'
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='/content/urn/test/images', update=False, view_img=False, weights=['/content/runs/train/urn_detection/weights/best.pt'])
# Using torch 1.7.0+cu101 CUDA:0 (Tesla T4, 15079MB)
#
# Fusing layers...
# Model Summary: 232 layers, 7246518 parameters, 0 gradients
# image 1/42 /content/urn/test/images/%D0%BF%D0%B0%D1%80%D0%B0%D0%BC%D0%BE%D0%BD%D0%BE%D_jpg.rf.8484d5bcaa09b4f1d967ac22bbf44516.jpg: 640x640 2 urns, Done. (0.012s)
# image 2/42 /content/urn/test/images/0c48f59228203ee49777d301a71e0dd1_jpg.rf.b01b0c6a6dffbdb77a064a8e6ce9f3cc.jpg: 640x640 1 urns, Done. (0.012s)
# image 3/42 /content/urn/test/images/1583392751_2039523313_720-480_jpg.rf.c3c9b80027620a615a798107a073b193.jpg: 640x640 1 urns, Done. (0.012s)
# ...
